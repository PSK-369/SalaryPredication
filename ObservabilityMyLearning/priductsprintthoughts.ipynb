# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns 
import statistics as sts 
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,precision_score,recall_score
from sklearn.preprocessing import LabelEncoder,StandardScaler,MinMaxScaler,OneHotEncoder

# %%
#Data Collection last few months shravan data
dataFrame1=pd.read_csv(r"C:\Shravan\PythonPratice\supervised\MyObservabilityQueue.csv",encoding_errors='ignore')

# %%
#Data information
dataFrame1.info()
dataFrame1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              607 non-null    int64
#  1   Work Item Type  607 non-null    object
#  2   Title           607 non-null    object
#  3   Assigned To     607 non-null    object
#  4   State           607 non-null    object
#  5   Tags            555 non-null    object
#  6   Created By      607 non-null    object
#  7   Actual Time     266 non-null    float64
#  8   Closed Status   0 non-null      float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 42.8+ KB
#                  ID  Actual Time  Closed Status
# count    607.000000   266.000000            0.0
# mean   16153.566722     3.112782            NaN
# std      929.694283     2.978613            NaN
# min    13695.000000     0.000000            NaN
# 25%    15403.000000     1.000000            NaN
# ...

# %%
#Missing and null values checks
dataFrame1.isna().sum()  # missing data
# Out:
# ID                  0
# Work Item Type      0
# Title               0
# Assigned To         0
# State               0
# Tags               52
# Created By          0
# Actual Time       341
# Closed Status     607
# dtype: int64

# %%
dataFrame1.isnull().sum()  # find the null data
# Out:
# ID                  0
# Work Item Type      0
# Title               0
# Assigned To         0
# State               0
# Tags               52
# Created By          0
# Actual Time       341
# Closed Status     607
# dtype: int64

# %%
#sample data
dataFrame1.sample(10)
# Out:
#         ID        Work Item Type  \
# 132  15261                  Task
# 247  15818                  Task
# 144  15302  Product Backlog Item
# 428  16673                  Task
# 365  16487                  Task
# 81   15070  Product Backlog Item
# 29   14668  Product Backlog Item
# 51   14901  Product Backlog Item
# 166  15502  Product Backlog Item
# 344  16367  Product Backlog Item
#
#                                                  Title  \
# 132                         Transfomrtion deployements
# 247                             Logstash user creation
# 144                       RITM0547669- Tristan || eESB
# 428                Tentacle ports followups and checks
# 365                        Support (update URL script)
# 81                   Servicenow - Tickets : INC3266971
# 29                                  INC3056578 - eESB
# 51                  Servicenow tickets: || RITM0568108
# 166                        RITM0613217 - userid - 1004
# ...

# %%
#filling data
