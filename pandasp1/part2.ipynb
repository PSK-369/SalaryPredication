# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns 
import statistics as sts

# %%
np.random.seed(42)
data=np.random.randint(low=1,high=100,size=(200)).astype(int)
data

df1=pd.DataFrame(data=data,columns=['data'])
df1
# Out:
#      data
# 0      52
# 1      93
# 2      15
# 3      72
# 4      61
# ..    ...
# 195    70
# 196    72
# 197    27
# 198     9
# 199    62
#
# [200 rows x 1 columns]

# %%
overall_mean=sts.mean(df1['data'])
overall_standard_deviations=sts.stdev(df1['data'])
sample_data=df1['data'].sample(40)

sample_mean=sts.mean(sample_data)
sample_count=20
print(f"{overall_mean} -> {overall_standard_deviations} -> {sample_mean} --> {sample_count}")
# Out:
# 49.365 -> 29.390487898203943 -> 50.15 --> 20

# %%
class Testing:
    def __init__(self,complete_mean,sample_mean,standard_deviations,sample_size):
        self.complete_mean=complete_mean
        self.sample_mean=sample_mean
        self.standard_deviations=standard_deviations
        self.sample_size=sample_size
        
 
class Z_test(Testing):
    def __init__(self,complete_mean,sample_mean,standard_deviations,sample_size):
        Testing.__init__(self,complete_mean,sample_mean,standard_deviations,sample_size)
    def calculate_function(self):
        result=(self.complete_mean-self.sample_mean)/(self.standard_deviations-np.sqrt(self.sample_size))
        return result
    
class T_test(Testing):
    def __init__(self,complete_mean,sample_mean,standard_deviations,sample_size):
        Testing.__init__(self,complete_mean,sample_mean,standard_deviations,sample_size)
    def calculate_function1(self):
        result=(self.complete_mean-self.sample_mean)/(self.standard_deviations-np.sqrt(self.sample_size))
        return result
    def calculate_df(self):
        result1=self.sample_mean-1
        return result1
    
class Annova_test(Testing):
    def __init__(self):
        pass


class HyperCase_test:
      pass

z_testing1=Z_test(overall_mean,sample_mean,overall_standard_deviations,sample_count)
new_test_results=z_testing1.calculate_function()
print(new_test_results)

t_testing1=T_test(overall_mean,sample_mean,overall_standard_deviations,sample_count)
new_t_test_results=t_testing1.calculate_function1()
new_t_test_results_df=t_testing1.calculate_df()

print(f"{new_t_test_results} and {new_t_test_results_df}")
# Out:
# -0.031502885976938726
# -0.031502885976938726 and 49.15

# %%
import numpy as np
import pandas as pd 
from
# Out:
#   Cell In[7], line 3
#     from
#          ^
# SyntaxError: invalid syntax
