# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import statistics as sts 
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler,MinMaxScaler,PolynomialFeatures
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression,Ridge,Lasso,ElasticNet
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score,f1_score,mean_absolute_error,mean_squared_error,root_mean_squared_error,root_mean_squared_log_error,confusion_matrix,classification_report
from sklearn.pipeline import Pipeline,make_pipeline

# %%
dataframe1=pd.read_csv(r"C:\Shravan\PythonPratice\employeechurn data\Employeeschrundata01.csv",encoding_errors='ignore')

# %%
dataframe1.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
dataframe1.sample(3)
# Out:
#       No First Name Last Name  Gender  Start Date  Years       Department  \
# 174  175     Muwmin      Ewad    Male  06-06-2017      8  Quality Control
# 108  109       Juri    Zaytun  Female  11-09-2020      5        Marketing
# 154  155     Rwbyna  Iibrahim  Female  05-03-2019      6               IT
#
#                   Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 174  United Arab Emirates   Main            1482          17784       5.0
# 108                 Egypt  North            2527          30324       3.0
# 154  United Arab Emirates  North            1960          23520       2.0
#
#      Sick Leaves  Unpaid Leaves  Overtime Hours
# 174            0              0               3
# 108            3              0              16
# 154            0              0               8

# %%
c3=['#f18a18','#ffffff']
sns.set_theme(style='white',palette=c3)
plt.figure(figsize=(8,5))
sns.pairplot(dataframe1)
plt.show()

# %%
c3=['#ff4d00','#ffffff']
sns.set_theme(style='white',palette=c3)
plt.figure(figsize=(8,5))
sns.scatterplot(data=dataframe1,x=dataframe1['Annual Salary'].head(50),y=dataframe1['Department'].head(50))
plt.grid(True)
plt.show()

# %%
c3=["#fd4d00",'#000000']
sns.set_theme(palette=c3)
plt.figure(figsize=(8,5))
sns.barplot(data=dataframe1,x=dataframe1['Country'],y=dataframe1['Monthly Salary'],orient='v',capsize=0.5)
plt.grid(True)
plt.show()

# %%
c3=["#ff4d01",'#000000']
sns.set_theme(palette=c3)
plt.figure(figsize=(8,5))
sns.boxplot(data=dataframe1,x=dataframe1['Country'],y=dataframe1['Monthly Salary'],orient='v')
plt.grid(True)
plt.show()
