# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns
import statistics as sts 
from scipy.spatial import distance as dts 
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error,mean_squared_error,median_absolute_error,root_mean_squared_error,r2_score,classification_report
import joblib as jib

# %%
def Sample_prints(dataFrame):
   print(dataFrame.info())
   print("===================")
   print(dataFrame.describe())
   print("==================")
   print(dataFrame.columns)
   print("=================")
   print(dataFrame.size)
   print("=================")
   print(dataFrame.ndim)
   print("===================")
   print("======================")
   print(f"{dataFrame.tail(10)}")
   print("==============")
   print(dataFrame.shape)
   print("================")
   print(dataFrame.isna().sum())
   print("====================")
   print(dataFrame.isnull().sum())
   print("==============")


try:
    df=pd.read_csv(r"F:\ExternalSoftwares\pythoncodes\MachineLearning\Salary Data.csv",encoding_errors='ignore')
    df.drop_duplicates(inplace=True)
    Sample_prints(df)
except Exception as e:
    print(f"error is {e}")
else:
    print("no errors")
finally:
    print("With and without erros final block it will print")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 325 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  324 non-null    float64
#  1   Gender               324 non-null    object
#  2   Education Level      324 non-null    object
#  3   Job Title            324 non-null    object
#  4   Years of Experience  324 non-null    float64
#  5   Salary               324 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.8+ KB
# None
# ...
#               Age  Years of Experience         Salary
# count  324.000000           324.000000     324.000000
# mean    37.382716            10.058642   99985.648148
# std      7.185844             6.650470   48652.271440
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.500000             9.000000   95000.000000
# ...

# %%
df.sample(10)
# Out:
#       Age  Gender Education Level                            Job Title  \
# 265  29.0  Female      Bachelor's          Junior Sales Representative
# 1    28.0  Female        Master's                         Data Analyst
# 319  37.0    Male      Bachelor's  Senior Business Development Manager
# 166  40.0  Female      Bachelor's               Senior Account Manager
# 185  43.0    Male      Bachelor's            Senior IT Project Manager
# 74   42.0  Female        Master's                    Creative Director
# 241  29.0    Male      Bachelor's              Junior Business Analyst
# 61   29.0    Male      Bachelor's                    Marketing Analyst
# 24   41.0    Male        Master's                    Financial Manager
# 323  47.0    Male             PhD              Director of Engineering
#
#      Years of Experience    Salary
# 265                  1.5   40000.0
# 1                    3.0   65000.0
# 319                 10.0  120000.0
# 166                 14.0  110000.0
# ...

# %%
lb=LabelEncoder()


df['Gender']=lb.fit_transform(df['Gender'])

df['Gender_inverted']=lb.inverse_transform(df['Gender'])

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# Sample data
df = pd.DataFrame({
    'age': [25, 30, 35, None],
    'income': [50000, 60000, 70000, 80000],
    'city': ['NY', 'LA', 'NY', 'SF']
})

# Define transformers
numeric_features = ['age', 'income']
categorical_features = ['city']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine using ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# Fit and transform
X_processed = preprocessor.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 17
#      14 numeric_features = ['age', 'income']
#      15 categorical_features = ['city']
# ---> 17 numeric_transformer = Pipeline(steps=[
#      18     ('imputer', SimpleImputer(strategy='median')),
#      19     ('scaler', StandardScaler())
#      20 ])
#      22 categorical_transformer = Pipeline(steps=[
#      23     ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
#      24     ('onehot', OneHotEncoder(handle_unknown='ignore'))
#      25 ])
#      27 # Combine using ColumnTransformer
#
# NameError: name 'Pipeline' is not defined
